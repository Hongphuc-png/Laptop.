# %% [markdown]
# # Mục mới

# %% [markdown]
# #Need to use 'Feature Engineering' to identify
# #Splitting the data.
# - 'data': dataset
# - 'x': 'data[features]'
# - 'y': target variable 'SalePrice'

# %%
#Import libraries
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("LaptopDataset_Final (2).csv")

# %%
data.head()
# Out:
#   Customer ID   OrderID  Channel PaymentType Brand           Shop Promotion  \
# 0    CTM80210    OTS636  Offline         Thẻ  Acer           Khác     Không
# 1     CTM1028  OTS92355   Online         Thẻ  Acer   Viễn thông A     Không
# 2    CTM10516    OTS842   Online         Thẻ  Asus  Điện máy xanh     Không
# 3    CTM10573  OTS51473   Online         Thẻ  Acer       FPT Shop        Có
# 4    CTM10573  OTS67163   Online         Thẻ    HP       Techcare     Không
#
#    SalePrice    SaleDate                                          Reference  \
# 0    7430000    1/2/2020                       Thông qua người thân, bạn bè
# 1   20013000  12/26/2020  Thông qua người thân, bạn bè, Nhờ người có chu...
# 2   19950000   9/24/2020  Thông qua người thân, bạn bè, Nhờ người có chu...
# 3   13513000   3/10/2020  Thông qua người thân, bạn bè, Nhờ người có chu...
# 4   49197000   2/22/2020  Thông qua người thân, bạn bè, Nhờ người có chu...
#
# ...

# %%
data = pd.read_csv("LaptopDataset_Final (2).csv", index_col = CustomerID)

# %%
data. columns
# Out:
# Index(['Customer ID', 'OrderID', 'Channel', 'PaymentType', 'Brand', 'Shop',
#        'Promotion', 'SalePrice', 'SaleDate', 'Reference', 'GioiTinh',
#        'QueQuan', 'NamHocThu', 'NgheNghiepGiaDinh', 'ChiTieuHangThang',
#        'ThoiGianSuDung', 'ChuyenNganh', 'MucDichSuDungLaptop', 'MucDoHaiLong',
#        'YeuToThuongHieuSP', 'YeuToCauHinh', 'YeuToTocDoXuLy', 'YeuToGia',
#        'YeuToThietKe', 'YeuToUyTinNhaBanle', 'YeuToBaoMat', 'YeuToBaoHanh',
#        'YeuToKhuyenMai'],
#       dtype='object')

# %%
features = ("Brand", "ChuyenNganh", "NgheNghiepGiaDinh", "ChiTieuHangThang", "NamHocThu", "ThoiGianSuDung")

# %%
x = data[list(features)]
y = data["SalePrice"]

# %%
x = data 'features'

# %%
y = data["SalePrice"]
display(y.head())
# Out:
# 0     7430000
# 1    20013000
# 2    19950000
# 3    13513000
# 4    49197000
# Name: SalePrice, dtype: int64

# %%
x = data[list(features)]
display(x.head())
# Out:
#   Brand             ChuyenNganh NgheNghiepGiaDinh            ChiTieuHangThang  \
# 0  Acer      Quản trị Marketing          Nông dân  Từ 3.000.000 đến 5.000.000
# 1  Acer      Thương mại điện tử          Nông dân  Từ 1.500.000 đến 3.000.000
# 2  Asus              Thương mại          Nông dân  Từ 1.500.000 đến 3.000.000
# 3  Acer  Tài chính doanh nghiệp          Nông dân  Từ 1.500.000 đến 3.000.000
# 4    HP  Tài chính doanh nghiệp          Nông dân  Từ 1.500.000 đến 3.000.000
#
#   NamHocThu      ThoiGianSuDung
# 0     Năm 3  Từ 1 năm đến 2 năm
# 1     Năm 3          Trên 2 năm
# 2     Năm 2  Từ 1 năm đến 2 năm
# 3     Năm 4          Trên 2 năm
# 4     Năm 4          Trên 2 năm
# WARNING: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.

# %%
x = data[list(features)]
display(x.head())
# Out:
#   Brand             ChuyenNganh NgheNghiepGiaDinh            ChiTieuHangThang  \
# 0  Acer      Quản trị Marketing          Nông dân  Từ 3.000.000 đến 5.000.000
# 1  Acer      Thương mại điện tử          Nông dân  Từ 1.500.000 đến 3.000.000
# 2  Asus              Thương mại          Nông dân  Từ 1.500.000 đến 3.000.000
# 3  Acer  Tài chính doanh nghiệp          Nông dân  Từ 1.500.000 đến 3.000.000
# 4    HP  Tài chính doanh nghiệp          Nông dân  Từ 1.500.000 đến 3.000.000
#
#   NamHocThu      ThoiGianSuDung
# 0     Năm 3  Từ 1 năm đến 2 năm
# 1     Năm 3          Trên 2 năm
# 2     Năm 2  Từ 1 năm đến 2 năm
# 3     Năm 4          Trên 2 năm
# 4     Năm 4          Trên 2 năm
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['ChuyenNganh'].value_counts()
    for x_label, grp in _df_4.groupby('Brand')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('Brand')
_ = plt.ylabel('ChuyenNganh')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['ThoiGianSuDung'].value_counts()
    for x_label, grp in _df_7.groupby('NamHocThu')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('NamHocThu')
_ = plt.ylabel('ThoiGianSuDung')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_3.groupby('NamHocThu').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_0.groupby('Brand').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# **3.2 x,y -> x_train, y train, x_valid, y_valid**

# %%
from sklearn.model_selection import train_test_split
x_train, x_valid, y_train, y_valid = train_test_split(x,y, train_size=0.8, test_size=0.2, random_state=0)

# %%
x_train.shape
# Out:
# (1244, 6)

# %%
x.shape
# Out:
# (1556, 6)

# %%
data.shape
# Out:
# (1556, 28)

# %%
1244/1556
# Out:
# 0.7994858611825193

# %%
x_valid.shape
# Out:
# (312, 6)

# %% [markdown]
# 4. Training machine learning model

# %%
from sklearn.tree import DecisionTreeRegressor
dt_model = DecisionTreeRegressor(random_state=1)

# %% [markdown]
# #Fit training data into model

# %%
from sklearn.tree import DecisionTreeRegressor
dt_model = DecisionTreeRegressor(random_state=1)
dt_model.fit(x_train, y_train)

# %% [markdown]
# ### 4.1 Feature Engineering: One-Hot Encoding

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# Identify categorical features
categorical_features = x_train.select_dtypes(include=['object']).columns

# Create a ColumnTransformer to apply one-hot encoding to categorical features
preprocessor = ColumnTransformer(
    transformers=[
        ('onehot', OneHotEncoder(handle_unknown='ignore'), categorical_features)
    ],
    remainder='passthrough' # Keep other columns (if any)
)

# Create a pipeline that first preprocesses the data and then trains the model
model_pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                                 ('regressor', DecisionTreeRegressor(random_state=1))])

# Fit the pipeline on the training data
model_pipeline.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehot',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   Index(['Brand', 'ChuyenNganh', 'NgheNghiepGiaDinh', 'ChiTieuHangThang',
#        'NamHocThu', 'ThoiGianSuDung'],
#       dtype='object'))])),
#                 ('regressor', DecisionTreeRegressor(random_state=1))])

# %% [markdown]
# ### 4.2 Model Training (with preprocessing)

# %%
# The model is already trained as part of the pipeline in the previous step.
# You can now use the 'model_pipeline' for predictions.

# %% [markdown]
# ### 5. Make Predictions

# %%
# Make predictions on the validation data using the trained pipeline
y_predict = model_pipeline.predict(x_valid)
display(y_predict[:5]) # Display the first 5 predictions
# Out:
# array([14060000., 10407000., 19243000., 13056000.,  7430000.])

# %% [markdown]
# ### 6. Evaluate Model

# %%
from sklearn.metrics import mean_absolute_error

# Calculate the Mean Absolute Error (MAE) on the validation data
mae = mean_absolute_error(y_valid, y_predict)
print(f"Mean Absolute Error (MAE): {mae}")
# Out:
# Mean Absolute Error (MAE): 6842187.500000001

# %%
y_predict= dt_model.predict (x_valid.head())

# %%
y_predict

# %%
import pandas as pd
comparison_df = pd.DataFrame({'Actual': y_valid.head(), 'Predicted': y_predict[:5]})
display(comparison_df)
# Out:
#         Actual   Predicted
# 319   14260000  14060000.0
# 1039  16240000  10407000.0
# 642   13720000  19243000.0
# 579   14219000  13056000.0
# 414   10046000   7430000.0

# %%
from sklearn.ensemble import RandomForestRegressor
rf_model = RandomForestRegressor (random_state=1)
rf_model.fit(x_train, y_train)

# %%
rf_value_predicts = rf_model.predict(x_valid)
rf_value_predicts[:5]

# %% [markdown]
# **Predict with a new input**

# %%
x_valid.head()
# Out:
#       Brand         ChuyenNganh NgheNghiepGiaDinh            ChiTieuHangThang  \
# 319   Apple  Quan hệ công chúng  Kinh doanh tự do  Từ 1.500.000 đến 3.000.000
# 1039   Dell        Toán kinh tế  Kinh doanh tự do  Từ 3.000.000 đến 5.000.000
# 642    Asus  Thương mại điện tử  Kinh doanh tự do  Từ 3.000.000 đến 5.000.000
# 579     MSI        Luật kinh tế          Nông dân              Dưới 1.500.000
# 414    Asus  Quản trị Marketing          Nông dân  Từ 3.000.000 đến 5.000.000
#
#      NamHocThu      ThoiGianSuDung
# 319      Năm 4  Từ 6 tháng - 1 năm
# 1039     Năm 3  Từ 1 năm đến 2 năm
# 642      Năm 4          Trên 2 năm
# 579      Năm 1  Từ 1 năm đến 2 năm
# 414      Năm 3  Từ 1 năm đến 2 năm

# %%
import pandas as pd
new_input = pd.DataFrame([['Lenovo', 'Buôn bán', 'Kinh doanh tự do', 'Từ 2.000.000 đến 6.000.000', 'Năm 2', 'Từ 7 tháng đến 3 năm']], columns=features)
rf_model_pipeline.predict(new_input)
# Out:
# array([13737440.])

# %% [markdown]
# #Model Evaluation

# %% [markdown]
# Đánh giá mô hình machine learning

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import pandas as pd
import numpy as np # Import numpy for median calculation

# Create a simple binary classification target for demonstration
# Let's define 'High Price' as SalePrice above the median, and 'Low Price' otherwise.
median_price = data['SalePrice'].median()
y_classification = data['SalePrice'].apply(lambda x: 'High Price' if x > median_price else 'Low Price')

# Encode the target variable into numerical labels
label_encoder = LabelEncoder()
y_classification_encoded = label_encoder.fit_transform(y_classification)

# Split data for classification
x_train_clf, x_valid_clf, y_train_clf, y_valid_clf = train_test_split(x, y_classification_encoded, test_size=0.2, random_state=0)

# Apply the same preprocessing pipeline to the classification data
# We'll reuse the 'preprocessor' from the regression task
# Note: The preprocessor was defined earlier based on the regression task's x_train.
# If the features for the classification task were different, a new preprocessor would be needed.
# Assuming the features (x) are the same for this demonstration:
x_train_clf_processed = preprocessor.fit_transform(x_train_clf)
x_valid_clf_processed = preprocessor.transform(x_valid_clf)


# Train a simple Decision Tree Classifier model
clf_model = DecisionTreeClassifier(random_state=1)
clf_model.fit(x_train_clf_processed, y_train_clf)

# Make predictions on the validation set
y_predict_clf = clf_model.predict(x_valid_clf_processed)

# Calculate Classification Metrics
accuracy = accuracy_score(y_valid_clf, y_predict_clf)
precision = precision_score(y_valid_clf, y_predict_clf)
recall = recall_score(y_valid_clf, y_predict_clf)
f1 = f1_score(y_valid_clf, y_predict_clf)
conf_matrix = confusion_matrix(y_valid_clf, y_predict_clf)

print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1-score: {f1}")
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Accuracy: 0.5865384615384616
# Precision: 0.6074074074074074
# Recall: 0.5189873417721519
# F1-score: 0.5597269624573379
# Confusion Matrix:
# [[101  53]
#  [ 76  82]]

# %% [markdown]
# ### Recommendations for Improving Classification Metrics

# %% [markdown]
# # Task
# Implement and evaluate multiple classification models (Random Forest, LightGBM, SVM, Logistic Regression) on the provided preprocessed data (`x_train_clf_processed`, `y_train_clf`, `x_valid_clf_processed`, `y_valid_clf`), calculate and display the Accuracy, Precision, Recall, F1-score, and Confusion Matrix for each model, and finally compare their performance to recommend the best model.

# %% [markdown]
# ## Implement and evaluate random forest classifier
#
# ### Subtask:
# Train a Random Forest Classifier using the preprocessed classification data (`x_train_clf_processed`, `y_train_clf`) and evaluate its performance using Accuracy, Precision, Recall, F1-score, and Confusion Matrix on the validation data (`x_valid_clf_processed`, `y_valid_clf`).

# %% [markdown]
# **Reasoning**:
# The subtask requires training a Random Forest Classifier, making predictions, and evaluating its performance using several metrics and the confusion matrix. This involves importing the necessary model, fitting it to the training data, predicting on the validation data, and calculating the evaluation metrics. All these steps can be performed in a single code block.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# Instantiate a RandomForestClassifier
rf_clf_model = RandomForestClassifier(random_state=1)

# Fit the Random Forest model to the preprocessed training data
rf_clf_model.fit(x_train_clf_processed, y_train_clf)

# Make predictions on the preprocessed validation data
y_predict_rf = rf_clf_model.predict(x_valid_clf_processed)

# Calculate Classification Metrics
accuracy_rf = accuracy_score(y_valid_clf, y_predict_rf)
precision_rf = precision_score(y_valid_clf, y_predict_rf)
recall_rf = recall_score(y_valid_clf, y_predict_rf)
f1_rf = f1_score(y_valid_clf, y_predict_rf)
conf_matrix_rf = confusion_matrix(y_valid_clf, y_predict_rf)

# Print the calculated metrics
print(f"Random Forest Classifier Performance:")
print(f"Accuracy: {accuracy_rf}")
print(f"Precision: {precision_rf}")
print(f"Recall: {recall_rf}")
print(f"F1-score: {f1_rf}")
print("Confusion Matrix:")
print(conf_matrix_rf)
# Out:
# Random Forest Classifier Performance:
# Accuracy: 0.6089743589743589
# Precision: 0.625
# Recall: 0.569620253164557
# F1-score: 0.5960264900662252
# Confusion Matrix:
# [[100  54]
#  [ 68  90]]

# %% [markdown]
# ## Implement and evaluate gradient boosting classifier (lightgbm)
#
# ### Subtask:
# Train a LightGBM Classifier using the preprocessed classification data and evaluate its performance using the same classification metrics on the validation data.

# %% [markdown]
# **Reasoning**:
# Import the LightGBM classifier and train the model on the preprocessed training data.

# %%
from lightgbm import LGBMClassifier

# Instantiate an LGBMClassifier
lgbm_clf_model = LGBMClassifier(random_state=1)

# Fit the LightGBM model to the preprocessed training data
lgbm_clf_model.fit(x_train_clf_processed, y_train_clf)
# Out:
# [LightGBM] [Info] Number of positive: 624, number of negative: 620
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000285 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 84
# [LightGBM] [Info] Number of data points in the train set: 1244, number of used features: 42
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.501608 -> initscore=0.006431
# [LightGBM] [Info] Start training from score 0.006431
# LGBMClassifier(random_state=1)

# %% [markdown]
# **Reasoning**:
# Make predictions using the trained LightGBM model and evaluate its performance using classification metrics.

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# Make predictions on the preprocessed validation data
y_predict_lgbm = lgbm_clf_model.predict(x_valid_clf_processed)

# Calculate Classification Metrics
accuracy_lgbm = accuracy_score(y_valid_clf, y_predict_lgbm)
precision_lgbm = precision_score(y_valid_clf, y_predict_lgbm)
recall_lgbm = recall_score(y_valid_clf, y_predict_lgbm)
f1_lgbm = f1_score(y_valid_clf, y_predict_lgbm)
conf_matrix_lgbm = confusion_matrix(y_valid_clf, y_predict_lgbm)

# Print the calculated metrics
print(f"LightGBM Classifier Performance:")
print(f"Accuracy: {accuracy_lgbm}")
print(f"Precision: {precision_lgbm}")
print(f"Recall: {recall_lgbm}")
print(f"F1-score: {f1_lgbm}")
print("Confusion Matrix:")
print(conf_matrix_lgbm)
# Out:
# LightGBM Classifier Performance:
# Accuracy: 0.6153846153846154
# Precision: 0.6283783783783784
# Recall: 0.5886075949367089
# F1-score: 0.6078431372549019
# Confusion Matrix:
# [[99 55]
#  [65 93]]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ## Implement and evaluate support vector machine (svm)
#
# ### Subtask:
# Train an SVM Classifier using the preprocessed classification data and evaluate its performance using the same classification metrics on the validation data.

# %% [markdown]
# **Reasoning**:
# Import the necessary libraries, instantiate and train the SVM model, make predictions, calculate evaluation metrics, and display the results.

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# Instantiate an SVC
svm_clf_model = SVC(random_state=1)

# Fit the SVM model to the preprocessed training data
svm_clf_model.fit(x_train_clf_processed, y_train_clf)

# Make predictions on the preprocessed validation data
y_predict_svm = svm_clf_model.predict(x_valid_clf_processed)

# Calculate Classification Metrics
accuracy_svm = accuracy_score(y_valid_clf, y_predict_svm)
precision_svm = precision_score(y_valid_clf, y_predict_svm)
recall_svm = recall_score(y_valid_clf, y_predict_svm)
f1_svm = f1_score(y_valid_clf, y_predict_svm)
conf_matrix_svm = confusion_matrix(y_valid_clf, y_predict_svm)

# Print the calculated metrics
print(f"SVM Classifier Performance:")
print(f"Accuracy: {accuracy_svm}")
print(f"Precision: {precision_svm}")
print(f"Recall: {recall_svm}")
print(f"F1-score: {f1_svm}")
print("Confusion Matrix:")
print(conf_matrix_svm)
# Out:
# SVM Classifier Performance:
# Accuracy: 0.6185897435897436
# Precision: 0.6101694915254238
# Recall: 0.6835443037974683
# F1-score: 0.6447761194029851
# Confusion Matrix:
# [[ 85  69]
#  [ 50 108]]

# %% [markdown]
# ## Implement and evaluate logistic regression
#
# ### Subtask:
# Train a Logistic Regression model using the preprocessed classification data and evaluate its performance using the same classification metrics on the validation data.

# %% [markdown]
# **Reasoning**:
# Import the necessary libraries for Logistic Regression and metrics, instantiate the model, fit it to the training data, make predictions on the validation data, and calculate and print the evaluation metrics and confusion matrix.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# Instantiate a LogisticRegression model
lr_clf_model = LogisticRegression(random_state=1)

# Fit the Logistic Regression model to the preprocessed training data
lr_clf_model.fit(x_train_clf_processed, y_train_clf)

# Make predictions on the preprocessed validation data
y_predict_lr = lr_clf_model.predict(x_valid_clf_processed)

# Calculate Classification Metrics
accuracy_lr = accuracy_score(y_valid_clf, y_predict_lr)
precision_lr = precision_score(y_valid_clf, y_predict_lr)
recall_lr = recall_score(y_valid_clf, y_predict_lr)
f1_lr = f1_score(y_valid_clf, y_predict_lr)
conf_matrix_lr = confusion_matrix(y_valid_clf, y_predict_lr)

# Print the calculated metrics
print(f"Logistic Regression Classifier Performance:")
print(f"Accuracy: {accuracy_lr}")
print(f"Precision: {precision_lr}")
print(f"Recall: {recall_lr}")
print(f"F1-score: {f1_lr}")
print("Confusion Matrix:")
print(conf_matrix_lr)
# Out:
# Logistic Regression Classifier Performance:
# Accuracy: 0.592948717948718
# Precision: 0.5906432748538012
# Recall: 0.6392405063291139
# F1-score: 0.6139817629179332
# Confusion Matrix:
# [[ 84  70]
#  [ 57 101]]

# %% [markdown]
# ## Compare model performance
#
# ### Subtask:
# Create a summary of the evaluation metrics for all the models to compare their performance and identify the best-performing model for this classification task.

# %% [markdown]
# **Reasoning**:
# Create a DataFrame to summarize the evaluation metrics from all the trained models and display it.

# %%
# Create a dictionary to hold the metrics
metrics_data = {
    'Model': ['Random Forest', 'LightGBM', 'SVM', 'Logistic Regression'],
    'Accuracy': [accuracy_rf, accuracy_lgbm, accuracy_svm, accuracy_lr],
    'Precision': [precision_rf, precision_lgbm, precision_svm, precision_lr],
    'Recall': [recall_rf, recall_lgbm, recall_svm, recall_lr],
    'F1-score': [f1_rf, f1_lgbm, f1_svm, f1_lr]
}

# Create a Pandas DataFrame
metrics_df = pd.DataFrame(metrics_data)

# Display the DataFrame
display(metrics_df)
# Out:
#                  Model  Accuracy  Precision    Recall  F1-score
# 0        Random Forest  0.608974   0.625000  0.569620  0.596026
# 1             LightGBM  0.615385   0.628378  0.588608  0.607843
# 2                  SVM  0.618590   0.610169  0.683544  0.644776
# 3  Logistic Regression  0.592949   0.590643  0.639241  0.613982

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The Random Forest Classifier achieved an Accuracy of 0.609, Precision of 0.625, Recall of 0.570, and an F1-score of 0.596.
# *   The LightGBM Classifier achieved an Accuracy of 0.615, Precision of 0.628, Recall of 0.589, and an F1-score of 0.608.
# *   The SVM Classifier achieved an Accuracy of 0.619, Precision of 0.610, Recall of 0.684, and an F1-score of 0.645.
# *   The Logistic Regression model achieved an Accuracy of 0.593, Precision of 0.591, Recall of 0.639, and an F1-score of 0.614.
# *   Comparing the models, the SVM model had the highest Recall (0.684) and F1-score (0.645). The LightGBM model had the highest Accuracy (0.615).
#
# ### Insights or Next Steps
#
# *   The SVM model appears to be the best-performing model among those evaluated, based on its higher F1-score and Recall.
# *   Further hyperparameter tuning could potentially improve the performance of all models, especially the SVM and LightGBM, to potentially increase accuracy and further optimize the F1-score.
